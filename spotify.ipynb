# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %% [markdown]
# #Task 1.1: Overview of the project and its objectives
# .
# Task 1.2: Explanation of the dataset used (Spotify
# tracks, features, user data, etc.).

# %%
print("Rows:", df.shape)
print("Columns:", df.shape)
# Out:
# Rows: (170653, 19)
# Columns: (170653, 19)

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  str
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  str
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  str
#  15  popularity        170653 non-null  int64
# ...

# %%
#task 1.2 

df.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='str')

# %% [markdown]
# #Task 2.2: Inspect and clean the data (handle missing
# values, duplicates, etc.).
# Task 2.3: Perform exploratory data analysis (EDA) to
# understand the basic characteristics of the data.

# %%
# Check missing values
df.isnull().sum()
# Out:
# valence             0
# year                0
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
# Handle missing values
df = df.dropna()

# %%
# Verify cleaning
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# EDA

df['popularity'].hist()

plt.title('Popularity Distribution')
plt.xlabel('Popularity')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# #Task 3.1: Analyze the distribution of various features
# (e.g., danceability, energy, tempo).

# %%
df['danceability'].hist(bins=20)

plt.title('Distribution of Danceability')
plt.xlabel('Danceability')
plt.ylabel('Count')

plt.show()

# %%
df['energy'].hist(bins=20)

plt.title('Distribution of Energy')
plt.xlabel('Energy')
plt.ylabel('Count')

plt.show()

# %%
df['tempo'].hist(bins=20)

plt.title('Distribution of Tempo')
plt.xlabel('Tempo')
plt.ylabel('Count')

plt.show()

# %%
# comparison

df[['danceability', 'energy', 'tempo']].hist(figsize=(12,4))

plt.show()

# %%
# identification of trends over time

# Average popularity by year
df.groupby('year')['popularity'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
# Average energy by year
df.groupby('year')['energy'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
# Average danceability by year
df.groupby('year')['danceability'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# #Task 3.3: Examine Correlations Between Features

# %%
# Correlation matrix
df[['danceability','energy','tempo','valence','popularity']].corr()
# Out:
#               danceability    energy     tempo   valence  popularity
# danceability      1.000000  0.221967  0.001801  0.558946    0.199606
# energy            0.221967  1.000000  0.250865  0.353876    0.485005
# tempo             0.001801  0.250865  1.000000  0.171689    0.133310
# valence           0.558946  0.353876  0.171689  1.000000    0.014200
# popularity        0.199606  0.485005  0.133310  0.014200    1.000000

# %%
# Energy vs Danceability
import matplotlib.pyplot as plt

plt.scatter(df['energy'], df['danceability'])
plt.xlabel('Energy')
plt.ylabel('Danceability')
plt.show()

# %%
# Correlation heatmap
import seaborn as sns

sns.heatmap(df[['danceability','energy','tempo','valence','popularity']].corr(),annot=True)
plt.show()

# %% [markdown]
# #Task 3.4: Analyze user preferences and listening
# habits.

# %%
# Most popular songs
df[['name', 'artists', 'popularity']].sort_values('popularity', ascending=False).head(10)
# Out:
#                                           name  \
# 19611                                   Dakiti
# 19606                   Mood (feat. iann dior)
# 19618                                 Dynamite
# 19616                          Blinding Lights
# 19608          WAP (feat. Megan Thee Stallion)
# 19610                                positions
# 19612                  What You Know Bout Love
# 19615           Holy (feat. Chance The Rapper)
# 19607  For The Night (feat. Lil Baby & DaBaby)
# 19623                       you broke me first
#
#                                       artists  popularity
# 19611            ['Bad Bunny', 'Jhay Cortez']         100
# 19606               ['24kGoldn', 'iann dior']          99
# 19618                                 ['BTS']          97
# 19616                          ['The Weeknd']          96
# 19608      ['Cardi B', 'Megan Thee Stallion']          96
# 19610                       ['Ariana Grande']          96
# ...

# %%
# Popularity by year
df.groupby('year')['popularity'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# # Task 4.1: Create visualizations to represent key findings (e.g., bar charts, line graphs, scatter plots).

# %%
df['artists'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Artists')
plt.show()

# %%
df.groupby('year')['popularity'].mean().plot()
plt.title('Average Popularity by Year')
plt.show()


#line chart of avg popularity over time

# %%
plt.scatter(df['energy'], df['danceability'])
plt.xlabel('Energy')
plt.ylabel('Danceability')
plt.show()

# %% [markdown]
# # Task 4.2: Advanced Visualizations

# %%
#heatmap
import seaborn as sns

sns.heatmap(df[['danceability','energy','tempo', 'valence','popularity']].corr(),
    annot=True)

plt.show()

# %%
sns.pairplot(df[['danceability', 'energy', 'tempo', 'valence','popularity']])

plt.show()

# %% [markdown]
# #Task 5.1: Build predictive models to forecast song
# popularity.

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
X = df[['danceability','energy','tempo']]
y = df['popularity']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

lr = LinearRegression()
lr.fit(X_train,y_train)

pred1 = lr.predict(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)

pred2 = dt.predict(X_test)

# %%
print(pred1[:5])
print(pred2[:5])
# Out:
# [25.41761853 28.1074362  44.55486475 44.63306613 33.11460741]
# [22. 67. 65. 39. 43.]

# %%
print(y_test.head())
print(pred1[:5])
# Out:
# 46651     34
# 54328     61
# 11475     56
# 104042    44
# 133133    36
# Name: popularity, dtype: int64
# [25.41761853 28.1074362  44.55486475 44.63306613 33.11460741]

# %% [markdown]
# #Task 5.2: Model Evaluation

# %%
# model evaluation 

from sklearn.metrics import r2_score

print("Linear:", r2_score(y_test,pred1))
print("Tree:", r2_score(y_test,pred2))
# Out:
# Linear: 0.24187323878855949
# Tree: -0.35597552804014

# %%
dt = DecisionTreeRegressor(max_depth=5,min_samples_split=10,random_state=42)

dt.fit(X_train, y_train)

pred = dt.predict(X_test)

print(r2_score(y_test, pred))
# Out:
# 0.2795668814911324

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

lr.fit(X_train, y_train)

pred = lr.predict(X_test)

print(r2_score(y_test, pred))
# Out:
# 0.2418732387885596

# %%
# Decision Tree performance was improved by limiting tree depth and increasing minimum samples required for splitting

# Fine-tuning helped reduce overfitting and improved model performance.

# %% [markdown]
# # Task 6.1: Summarize Key Findings from the Analysis

# %%
# The Spotify dataset contains information about tracks, artists, popularity, and audio features such as danceability, energy, tempo, valence, and acousticness.

# Most songs have moderate to high danceability and energy levels.

# Song popularity varies across years, indicating changing listener preferences over time.

# Predictive models such as Linear Regression and Decision Tree Regression were used to forecast song popularity.

# Model performance was improved through feature scaling and parameter tuning.

# %% [markdown]
# # Task 6.2: Discuss the Implications of the Results

# %%
# Audio features play an important role in determining song popularity and listener engagement.

# Understanding feature relationships can help artists and producers create music that aligns with audience preferences.

# Trends over time indicate that music styles and listener tastes evolve continuously.

# %% [markdown]
# # Task 6.3: Suggest potential areas for future research.

# %%
# Incorporate user listening history and playlist data to better understand listener behavior and preferences.

# Analyze genre-specific trends to identify factors influencing the popularity of different music styles.

# Explore artist-related features such as collaborations, follower counts, and release frequency.

# Develop personalized music recommendation systems using user interaction data.

# %% [markdown]
# # Task 7.1: Document the entire analysis process,including code, methodology, and results.

# %%
# Spotify Data Analysis Report

# Introduction
This project analyzes Spotify track data to understand music characteristics, popularity trends, and relationships between audio features.

## Objectives
- Analyze Spotify track data.
- Explore audio features such as danceability, energy, and tempo.
- Identify trends over time.
- Predict song popularity using machine learning models.

## Dataset Description
The dataset contains Spotify tracks and audio features including:
- Popularity
- Danceability
- Energy
- Tempo
- Valence
- Acousticness
- Artists
- Release Year

## Data Cleaning
- Checked for missing values.
- Removed duplicate records.
- Verified data types.

## Exploratory Data Analysis
### Feature Distribution
- Analyzed danceability distribution.
- Analyzed energy distribution.
- Analyzed tempo distribution.

### Trend Analysis
- Examined popularity trends over time.
- Studied changes in audio features by year.

### Correlation Analysis
- Investigated relationships between audio features.
- Generated a correlation heatmap.

## Predictive Modeling
### Linear Regression
- Trained a Linear Regression model.
- Evaluated performance using R² score.

### Decision Tree Regression
- Trained a Decision Tree model.
- Compared performance with Linear Regression.

## Key Findings
- Popular songs tend to have higher danceability and energy.
- Several audio features show positive correlations.
- Machine learning models can predict popularity with moderate accuracy.

## Conclusion
The analysis provided insights into Spotify music characteristics and factors affecting song popularity.

# %% [markdown]
# # Task 7.2: Prepare a presentation to share findings with stakeholders.

# %% [markdown]
# # Spotify Data Analysis
# ### Project Presentation
#
#
# # Project Objectives
#
# - Analyze Spotify track data
# - Explore audio features
# - Identify popularity trends
# - Build prediction models
#
#
# # Dataset Overview
#
# - Spotify tracks dataset
# - Features:
#   - Popularity
#   - Danceability
#   - Energy
#   - Tempo
#   - Valence
#
#
# # Data Cleaning
#
# - Checked missing values
# - Removed duplicates
# - Verified data types
#
#
# # Exploratory Data Analysis
#
# - Danceability distribution
# - Energy distribution
# - Tempo distribution
#
#
# # Trend Analysis
#
# - Popularity over years
# - Feature changes over time
#
#
# # Correlation Analysis
#
# - Energy vs Danceability
# - Correlation Heatmap
#
# # Predictive Models
#
# - Linear Regression
# - Decision Tree Regression
#
#
# # Key Findings
#
# - Popular songs tend to be more danceable
# - Energy and popularity show relationships
# - Models can predict popularity
#
# # Future Scope
#
# - Recommendation systems
# - Advanced ML models
# - User listening analysis
